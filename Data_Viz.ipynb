# %% [markdown]
# # Data Visualization Exercise
#
# _March 18, 2021_

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1 - Create a 2x2 figure with matplotlib<br>
# 2 - Use 4 different types of plots for the following dataset

# %%
# read in the aq dataset
aq = pd.read_csv('aq.csv')

# %%
# look at the head of aq
aq.head()
# Out:
#    x123   x4    y1    y2     y3    y4
# 0  10.0  8.0  8.04  9.14   7.46  6.58
# 1   8.0  8.0  6.95  8.14   6.77  5.76
# 2  13.0  8.0  7.58  8.74  12.74  7.71
# 3   9.0  8.0  8.81  8.77   7.11  8.84
# 4  11.0  8.0  8.33  9.26   7.81  8.47

# %%
# subset the dataset to only include columns "x123" and "y1", and call the new dataframe aq1
aq1 = aq[['x123', 'y1']]

# %%
# create a 2x2 subplot, use figsize 10x10
fig , axes = plt.subplots(figsize = (10,10), ncols = 2, nrows = 2)

# %%
# define our x and y
x = aq1.x123
y = aq1.y1

# now create 4 graphs, the the upper left graph a scatter plot
# the bottom left a line plot
# the top right a histogram (just show x)
# the bottom right a bar plot


#starter code:
axes[0][0].scatter(x, y)
axes[1][0].plot(x,y)
axes[0][1].hist(x)
axes[1][1].bar(x,y)

fig

# %%
# Add titles to each of the axes objects

axes[0][0].set_title('Scatter plot')
axes[1][0].set_title('Line plot')
axes[0][1].set_title('Histogram')
axes[1][1].set_title('Bar chart')

fig

# %% [markdown]
# ## Level Up: Data Analysis Example & Using Seaborn

# %%
#loads tips dataset
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# visualize the relationship between bill and tip

# your code here

fig, axes = plt.subplots()
axes.scatter(x = tips.total_bill, y = tips.tip)
axes.set_title("Bill & Tip");


#bill_tip = tips[['total_bill', 'tip']]

#bill = tips.total_bill
#tip = tips.tip

#fig, ax = plt.subplots()

#ax.scatter(bill, tip)
#ax.set_title("Bill & Tip");

# %%
# visualize the average tips men vs women pay - what's the appropriate plot?

tip_mean = tips.groupby(['sex'])['tip'].mean()

print(tip_mean.index)
print(tip_mean.values)

plt.bar(tip_mean.index, tip_mean.values);
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, name='sex', dtype='category')
# [3.08961783 2.83344828]

# %%
# your turn - visualize the average amount of total bill for time (lunch or dinner)

time_mean = tips.groupby(['time'])['total_bill'].mean()

plt.bar(time_mean.index, time_mean.values);


#time_bill = tips[['time', 'total_bill']]

#lunch = time_bill[time_bill['time'] == 'Lunch']
#dinner = time_bill[time_bill['time'] == 'Dinner']

#avg_lunch = sum(lunch['total_bill']) / len(lunch['total_bill'])
#avg_dinner = sum(dinner['total_bill']) / len(dinner['total_bill'])

#label = ['Lunch', 'Dinner']
#avg_time = [avg_lunch, avg_dinner]

#fig, ax = plt.subplots()
#ax.bar(label, avg_time);

# %% [markdown]
# ## Resources

# %% [markdown]
# - https://www.ted.com/talks/david_mccandless_the_beauty_of_data_visualization#t-503926
# - https://realpython.com/python-matplotlib-guide/

# %% [markdown]
# - https://pudding.cool/
# - http://setosa.io/#/
